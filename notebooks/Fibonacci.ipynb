# %% [markdown]
# ### The Fibonacci Sequence and Generalizations
# This notebook is based on the project of the same title from Lay's Linear Algebra text.  It can be found here:
# [Lay's Fibonacci Project](https://media.pearsoncmg.com/aw/aw_lay_linearalg_updated_cw_5/student/applications/MatLab/MatLab_pdfs/ch5/Fibonacci.pdf)

# %%
import numpy as np
from numpy import linalg as LA
